# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
import random

# %% [markdown]
# # mens top wear

# %%
driver = webdriver.Chrome()
driver.get('https://www.flipkart.com/')

# %%
#clicking on mens 
s=driver.find_element(By.XPATH,'//div[@class="_3sdu8W emupdz"]/div[1]/div/div/span')
s.click()

# %%
# casual shirt
a = 'https://www.flipkart.com/mens-casual-shirts/pr?sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&fm=neo%2Fmerchandising&iid=M_f93446f6-7e0c-49aa-8ff7-c807b4653b83_1_372UD5BXDFYS_MC.S4ITKV5A4VL6&otracker=hp_rich_navigation_3_1.navigationCard.RICH_NAVIGATION_Fashion%7EMen%2527s%2BTop%2BWear%7EMen%2527s%2BCasual%2BShirts_S4ITKV5A4VL6&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_3_L2_view-all&cid=S4ITKV5A4VL6&p%5B%5D=facets.brand%255B%255D%3DAllen%2BSolly&p%5B%5D=facets.brand%255B%255D%3DHIGHLANDER&p%5B%5D=facets.brand%255B%255D%3DU.S.%2BPOLO%2BASSN.&p%5B%5D=facets.brand%255B%255D%3DThe%2BIndian%2BGarage%2BCo.&p%5B%5D=facets.brand%255B%255D%3DMUFTI'
b = 'https://www.flipkart.com/mens-formal-shirts/pr?sid=clo%2Cash%2Caxc%2Cmmk%2Cbk1&fm=neo%2Fmerchandising&iid=M_6309c625-637d-4758-bbd2-f4b8008544ae_1_372UD5BXDFYS_MC.V795R35ST9K6&otracker=hp_rich_navigation_4_1.navigationCard.RICH_NAVIGATION_Fashion%7EMen%2527s%2BTop%2BWear%7EMen%2527s%2BFormal%2BShirts_V795R35ST9K6&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_4_L2_view-all&cid=V795R35ST9K6&p%5B%5D=facets.brand%255B%255D%3DPETER%2BENGLAND&p%5B%5D=facets.brand%255B%255D%3DARROW&p%5B%5D=facets.brand%255B%255D%3DVAN%2BHEUSEN&p%5B%5D=facets.brand%255B%255D%3DRaymond'
c = 'https://www.flipkart.com/mens-tshirts/pr?sid=clo%2Cash%2Cank%2Cedy&fm=neo%2Fmerchandising&iid=M_97d27cdd-a78e-4891-877b-b47e9cb996a6_1_372UD5BXDFYS_MC.IF56C41VGEYS&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Fashion%7EMen%2527s%2BTop%2BWear%7EMen%2527s%2BT-Shirts_IF56C41VGEYS&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&cid=IF56C41VGEYS&p%5B%5D=facets.brand%255B%255D%3DPUMA&p%5B%5D=facets.brand%255B%255D%3DU.S.%2BPOLO%2BASSN.&p%5B%5D=facets.brand%255B%255D%3DADIDAS&p%5B%5D=facets.brand%255B%255D%3DAllen%2BSolly&p%5B%5D=facets.brand%255B%255D%3DTOMMY%2BHILFIGER'


MT = [a, b,c]

# %%
# Initialize empty lists for different shirt categories
formal_shirt = []
casual_shirt = []
t_shirt = []

driver = webdriver.Chrome()
# Loop through each URL in the list MT
for i in MT:
    driver.get(i)
    time.sleep(10)  # Wait for the page to load
    
    # Loop through pages 1 to 6 (assuming pagination)
    for page_number in [1, 2, 3, 4, 5, 6, 7,8]:
        driver.execute_script("window.scrollTo(0, 3800);")  # Scroll to the bottom of the page
        time.sleep(5)  # Wait for content to load
        
        # Find links for shirts
        links = driver.find_elements(By.XPATH, '//div[@class="_1xHGtK _373qXS"]/a')
        
        # Append links to the appropriate category list
        if i == a:
            for q in links:
                casual_shirt.append(q.get_attribute('href'))
        elif i == b:
            for q in links:
                formal_shirt.append(q.get_attribute('href'))
        else:
            for q in links:
                t_shirt.append(q.get_attribute('href'))
        
        time.sleep(5)  # Wait before clicking next page
        
        # Click on the next page button
        next_page_button = driver.find_element(By.XPATH, '//nav[@class="yFHi8N"]/a[11]/span |//nav[@class="yFHi8N"]/a[12]/span')
        next_page_button.click()
        time.sleep(5)  # Wait for the next page to load

# %%
driver = webdriver.Chrome()

# %%
ms_brand_name=[]
ms_product_name=[]
ms_price=[]
ms_product_code=[]
ms_product_type=[]
ms_category=[]

col1 = []
col2 = []
col3 = []
col4 = []
wr_type = []
m_type = []
reviews = []

size1 = []
size2 = []
size3 = []
size4 = []
r_time = []
occ = []
c_ori = []

for l in [formal_shirt, casual_shirt, t_shirt]:
    for link in l:
        driver.get(link)
        time.sleep(2)

        #Finding the Product price
        try:
            price_element=driver.find_element(By.XPATH,'//div[@class="_25b18c"]/div[1]')
            if price_element:
                ms_price.append(price_element.text.replace('₹',''))
            else:
                ms_price.append('----')
        except Exception as e:
            ms_price.append('----')
        
        #Finding the Product name
        try:
            pd_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[2]')
            if pd_element:
                ms_product_name.append(pd_element.text)
            else:
                ms_product_name.append('----')
        except Exception as e:
            ms_product_name.append('----')
           
        #adding brand name 
        try:
            pdc_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[1]')
            if pdc_element:
                ms_brand_name.append(pdc_element.text.replace('SKU : ',''))
            else:
                ms_brand_name.append('----')
            
        except Exception as e:
            ms_brand_name.append('----')
        
        #adding product code
        ms_product_code.append(random.randint(10000000, 99999999))
    
        #adding category
        ms_category.append('MEN')
    
    # scrapping colour
        try:
            clr1 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][1]/div/div]')
            col1.append(clr1.text.strip())
        except Exception as e:
            col1.append('blue')
        try:
            clr2 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][2]/div/div]')
            col2.append(clr2.text.strip())
        except Exception as e:
            col2.append('Grey')
        try:
            clr3 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][3]/div/div]')
            col3.append(clr3.text.strip())
        except Exception as e:
            col3.append('White')
        try:
            clr4 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][4]/div/div]')
            col4.append(clr4.get_attribute('title'))
        except Exception as e:
            col4.append('white')

        try:
            button = driver.find_element(By.XPATH, '//div[@class="_2yIA0Y"]/div/div[2]')
            button.click()
        except Exception as e:
            pass
        
        try: #scrapping material type
        # Loop through elements from index 2 to index 7
            for i in range(1, 8):
                head = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[1]')
                if head.text == "Fabric": 
                    mate = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[2]').text
                    m_type.append(mate)
                    break  # Exit the loop once "Occasion" is found
            else:
                m_type.append('-----')  # Append '-----' if "Occasion" is not found in any iteration
        except Exception as e:
            m_type.append('-----')
    
        # adding reviews # info not available
        reviews.append(random.randint(100, 10000))

        # scrapping size 
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[1]')
            size1.append(size.text.strip())
        except Exception as e:
            size1.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[2]')
            size2.append(size.text.strip())
        except Exception as e:
            size2.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[3]')
            size3.append(size.text.strip())
        except Exception as e:
            size3.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[4]')
            size4.append(size.text.strip())
        except Exception as e:
            size4.append('-----')
    
        #adding wear type
        wr_type.append('top wear')
        
        # adding return time
        r_time.append('10')
        
        # product type
        if l == formal_shirt:
            ms_product_type.append('formal shirt')
        elif l == casual_shirt:
            ms_product_type.append('casual shirt')
        else:
            ms_product_type.append('t shirt')       
        
        # occassion 
        if l == formal_shirt:
            occ.append('formal')
        elif l == casual_shirt:
            occ.append('casual')
        else:
            occ.append('regular')  
            
        # country of origin 
        c_ori.append('india')

# %%
data1 = pd.DataFrame({'Brand name' : ms_brand_name, 'category' : ms_category, 'product type' : ms_product_type,'product name' : ms_product_name, 'product code' : ms_product_code , 'price' :ms_price, 
                      'wear type' : wr_type, 'material type' : m_type,'colour 1' : col1, 'colour 2' :col2, 'colour 3' : col3, 'colour 4' : col4,  "reviews" : reviews,
                      "occasion" : occ, "return_ time" : r_time, "country _origin" : c_ori, 'size1' :size1, 'size2' :size2, 'size3' :size3, 'size4' :size4})
data1.to_csv('fdata1', index = False)
data1
# Out:
#            Brand name category  product type  \
# 0          METRONAUT       MEN  formal shirt
# 1          METRONAUT       MEN  formal shirt
# 2              ARROW       MEN  formal shirt
# 3            Raymond       MEN  formal shirt
# 4              ARROW       MEN  formal shirt
# ..                ...      ...           ...
# 711  U.S. POLO ASSN.       MEN       t shirt
# 712         Damensch       MEN       t shirt
# 713              ----      MEN       t shirt
# 714      Allen Solly       MEN       t shirt
# 715  U.S. POLO ASSN.       MEN       t shirt
#
#                                           product name  product code  price  \
# 0     Men Regular Fit Solid Spread Collar Formal Shirt      25330425    335
# 1    Men Regular Fit Solid Button Down Collar Forma...      30983827    389
# 2      Men Slim Fit Solid Cut Away Collar Formal Shirt      89038829  1,049
# 3                   Men Regular Fit Solid Formal Shirt      85757252  1,169
# ...

# %% [markdown]
# # mens bottom wear

# %%
driver = webdriver.Chrome()
driver.get('https://www.flipkart.com/')

# %%
#clicking on mens bottom wear
s=driver.find_element(By.XPATH,'//div[@class="_3sdu8W emupdz"]/div[1]/div/div/span')
s.click()

# %%
a = 'https://www.flipkart.com/mens-clothing/trousers/pr?sid=2oq%2Cs9b%2C9uj&otracker=nmenu_sub_Men_0_Casual+Trousers&p%5B%5D=facets.brand%255B%255D%3DVAN%2BHEUSEN&p%5B%5D=facets.brand%255B%255D%3DPETER%2BENGLAND&p%5B%5D=facets.brand%255B%255D%3DARROW&p%5B%5D=facets.brand%255B%255D%3DLOUIS%2BPHILIPPE&p%5B%5D=facets.brand%255B%255D%3DRaymond'
b = 'https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&p%5B%5D=facets.brand%255B%255D%3DRaymond&p%5B%5D=facets.brand%255B%255D%3DARROW&p%5B%5D=facets.brand%255B%255D%3DLOUIS%2BPHILIPPE&p%5B%5D=facets.brand%255B%255D%3DU.S.%2BPOLO%2BASSN.&p%5B%5D=facets.brand%255B%255D%3DAllen%2BSolly&p%5B%5D=facets.brand%255B%255D%3DPARK%2BAVENUE&p%5B%5D=facets.brand%255B%255D%3DVAN%2BHEUSEN&p%5B%5D=facets.brand%255B%255D%3DPETER%2BENGLAND'
c = 'https://www.flipkart.com/clothing-and-accessories/bottomwear/track-pants/men-track-pants/pr?sid=clo%2Cvua%2Cjlk%2C6ql&otracker=categorytree&otracker=nmenu_sub_Men_0_Track+pants&p%5B%5D=facets.brand%255B%255D%3DPUMA&p%5B%5D=facets.brand%255B%255D%3DADIDAS&p%5B%5D=facets.brand%255B%255D%3DHIGHLANDER&p%5B%5D=facets.brand%255B%255D%3DPETER%2BENGLAND&p%5B%5D=facets.brand%255B%255D%3DKILLER&p%5B%5D=facets.brand%255B%255D%3DU.S.%2BPOLO%2BASSN.'
d = 'https://www.flipkart.com/clothing-and-accessories/bottomwear/shorts/men-shorts/pr?sid=clo%2Cvua%2Ce8g%2Ckc7&otracker=categorytree&otracker=nmenu_sub_Men_0_Shorts&p%5B%5D=facets.occasion%255B%255D%3DSports&p%5B%5D=facets.brand%255B%255D%3DPUMA&p%5B%5D=facets.brand%255B%255D%3DADIDAS&p%5B%5D=facets.brand%255B%255D%3DWROGN&p%5B%5D=facets.brand%255B%255D%3DHIGHLANDER&p%5B%5D=facets.brand%255B%255D%3DU.S.%2BPOLO%2BASSN.'

tm = [a, b,c, d]

# %%
# Initialize empty lists for different shirt categories
formal_trouser = []
casual_trouser = []
t_pant = []
shorts = []

driver = webdriver.Chrome()
# Loop through each URL in the list MT
for i in tm:
    driver.get(i)
    time.sleep(10)  # Wait for the page to load
    
    # Loop through pages 1 to 6 (assuming pagination)
    for page_number in [1, 2, 3, 4, 5]:
        driver.execute_script("window.scrollTo(0, 3800);")  # Scroll to the bottom of the page
        time.sleep(5)  # Wait for content to load
        
        # Find links for shirts
        links = driver.find_elements(By.XPATH, '//div[@class="_1xHGtK _373qXS"]/a')
        
        # Append links to the appropriate category list
        if i == a:
            for q in links:
                casual_trouser.append(q.get_attribute('href'))
        elif i == b:
            for q in links:
                formal_trouser.append(q.get_attribute('href'))
        elif i == d:
            for q in links:
                shorts.append(q.get_attribute('href'))
        else:
            for q in links:
                t_pant.append(q.get_attribute('href'))
        
        time.sleep(5)  # Wait before clicking next page
        
        # Click on the next page button
        next_page_button = driver.find_element(By.XPATH, '//nav[@class="yFHi8N"]/a[11]/span |//nav[@class="yFHi8N"]/a[12]/span')
        next_page_button.click()
        time.sleep(5)  # Wait for the next page to load

# %%
ms_brand_name=[]
ms_product_name=[]
ms_price=[]
ms_product_code=[]
ms_product_type=[]
ms_category=[]

col1 = []
col2 = []
col3 = []
col4 = []
wr_type = []
m_type = []
reviews = []

size1 = []
size2 = []
size3 = []
size4 = []
r_time = []
occ = []
c_ori = []

driver = webdriver.Chrome()
for l in [formal_trouser, casual_trouser, t_pant, shorts]:
    for link in l:
        driver.get(link)
        time.sleep(2)

        #Finding the Product price
        try:
            price_element=driver.find_element(By.XPATH,'//div[@class="_25b18c"]/div[1]')
            if price_element:
                ms_price.append(price_element.text.replace('₹',''))
            else:
                ms_price.append('----')
        except Exception as e:
            ms_price.append('----')
        
        #Finding the Product name
        try:
            pd_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[2]')
            if pd_element:
                ms_product_name.append(pd_element.text)
            else:
                ms_product_name.append('----')
        except Exception as e:
            ms_product_name.append('----')
           
        #adding brand name 
        try:
            pdc_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[1]')
            if pdc_element:
                ms_brand_name.append(pdc_element.text.replace('SKU : ',''))
            else:
                ms_brand_name.append('----')
            
        except Exception as e:
            ms_brand_name.append('----')
        
        #adding product code
        ms_product_code.append(random.randint(10000000, 99999999))
    
        #adding category
        ms_category.append('MEN')
    
    # scrapping colour
        try:
            clr1 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][1]/div/div]')
            col1.append(clr1.text.strip())
        except Exception as e:
            col1.append('blue')
        try:
            clr2 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][2]/div/div]')
            col2.append(clr2.text.strip())
        except Exception as e:
            col2.append('Grey')
        try:
            clr3 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][3]/div/div]')
            col3.append(clr3.text.strip())
        except Exception as e:
            col3.append('White')
        try:
            clr4 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][4]/div/div]')
            col4.append(clr4.get_attribute('title'))
        except Exception as e:
            col4.append('white')
            
        try:
            button = driver.find_element(By.XPATH, '//div[@class="_2yIA0Y"]/div/div[2]')
            button.click()
        except Exception as e:
            pass
        
        try: #scrapping material type
        # Loop through elements from index 2 to index 7
            for i in range(1, 8):
                head = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[1]')
                if head.text == "Fabric": 
                    mate = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[2]').text
                    m_type.append(mate)
                    break  # Exit the loop once "Occasion" is found
            else:
                m_type.append('-----')  # Append '-----' if "Occasion" is not found in any iteration
        except Exception as e:
            m_type.append('-----')
    
        # adding reviews # info not available
        reviews.append(random.randint(100, 10000))

        # scrapping size 
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[1]')
            size1.append(size.text.strip())
        except Exception as e:
            size1.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[2]')
            size2.append(size.text.strip())
        except Exception as e:
            size2.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[3]')
            size3.append(size.text.strip())
        except Exception as e:
            size3.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[4]')
            size4.append(size.text.strip())
        except Exception as e:
            size4.append('-----')
    
        #adding wear type
        wr_type.append('bottom wear')
        
        # adding return time
        r_time.append('10')
        
        # product type
        if l == formal_trouser:
            ms_product_type.append('formal trouser')
        elif l == casual_trouser:
            ms_product_type.append('casual trouser')
        elif l == shorts:
            ms_product_type.append('regular')
        else:
            ms_product_type.append('sports wear')       
        
        # occassion 
        if l == formal_trouser:
            occ.append('formal')
        elif l == casual_trouser:
            occ.append('casual')
        else:
            occ.append('regular')  
            
        # country of origin 
        c_ori.append('india')

# %%
data2 = pd.DataFrame({'Brand name' : ms_brand_name, 'category' : ms_category, 'product type' : ms_product_type,'product name' : ms_product_name, 'product code' : ms_product_code , 'price' :ms_price, 
                      'wear type' : wr_type, 'material type' : m_type,'colour 1' : col1, 'colour 2' :col2, 'colour 3' : col3, 'colour 4' : col4,  "reviews" : reviews,
                      "occasion" : occ, "return_ time" : r_time, "country _origin" : c_ori, 'size1' :size1, 'size2' :size2, 'size3' :size3, 'size4' :size4})
data2.to_csv('fdata2', index = False)

# %%
data2
# Out:
#          Brand name category    product type  \
# 0        METRONAUT       MEN  formal trouser
# 1        METRONAUT       MEN  formal trouser
# 2          Raymond       MEN  formal trouser
# 3          Raymond       MEN  formal trouser
# 4    PETER ENGLAND       MEN  formal trouser
# ..              ...      ...             ...
# 793           PUMA       MEN         regular
# 794         ADIDAS       MEN         regular
# 795           PUMA       MEN         regular
# 796         ADIDAS       MEN         regular
# 797           PUMA       MEN         regular
#
#                                           product name  product code  price  \
# 0    Slim Fit Men Lycra Blend Light Blue Lycra Blen...      76420141    499
# 1      Slim Fit Men Polyester Green Polyester Trousers      68236625    399
# 2                Men Slim Fit Brown Polyester Trousers      95167369  1,079
# 3                Men Slim Fit Black Polyester Trousers      42791269    763
# ...

# %% [markdown]
# # womens top wear

# %%
driver = webdriver.Chrome()
driver.get('https://www.flipkart.com/')

# %%
#clicking on womens top wear
s=driver.find_element(By.XPATH,'//div[@class="_3sdu8W emupdz"]/div[1]/div/div/span')
s.click()

# %%
a = 'https://www.flipkart.com/clothing-and-accessories/topwear/pr?sid=clo%2Cash&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=categorytree&otracker=nmenu_sub_Women_0_Topwear&p%5B%5D=facets.occasion%255B%255D%3Dcasual&p%5B%5D=facets.ideal_for%255B%255D%3DWomen'
b = 'https://www.flipkart.com/clothing-and-accessories/topwear/pr?sid=clo%2Cash&p%5B%5D=facets.occasion%255B%255D%3Dcasual&otracker=categorytree&otracker=nmenu_sub_Women_0_Topwear&p%5B%5D=facets.occasion%255B%255D%3DParty&p%5B%5D=facets.brand%255B%255D%3DAllen%2BSolly&p%5B%5D=facets.brand%255B%255D%3DU.S.%2BPOLO%2BASSN.&p%5B%5D=facets.brand%255B%255D%3DTokyo%2BTalkies&p%5B%5D=facets.brand%255B%255D%3DHARPA&p%5B%5D=facets.brand%255B%255D%3DLOUIS%2BPHILIPPE&p%5B%5D=facets.brand%255B%255D%3DPLUSS&p%5B%5D=facets.ideal_for%255B%255D%3DWomen'
c = 'https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&p%5B%5D=facets.occasion%255B%255D%3Dcasual&p%5B%5D=facets.occasion%255B%255D%3DFormal' 
d = 'https://www.flipkart.com/clothing-and-accessories/topwear/pr?sid=clo%2Cash&p%5B%5D=facets.occasion%255B%255D%3Dcasual&otracker=categorytree&otracker=nmenu_sub_Women_0_Topwear&p%5B%5D=facets.occasion%255B%255D%3DFestive&p%5B%5D=facets.ideal_for%255B%255D%3DWomen'
tm = [a,b,c,d]

# %%
# Initialize empty lists for different shirt categories
ft_formal = []
ft_party = []
ft_festive = []

# %%
driver = webdriver.Chrome()
# Loop through each URL in the list MT
for i in tm:
    driver.get(i)
    time.sleep(10)  # Wait for the page to load
    
    # Loop through pages 1 to 6 (assuming pagination)
    for page_number in [1, 2, 3, 4]:
        driver.execute_script("window.scrollTo(0, 3300);")  # Scroll to the bottom of the page
        time.sleep(5)  # Wait for content to load
        
        # Find links for shirts
        links = driver.find_elements(By.XPATH, '//div[@class="_1xHGtK _373qXS"]/a')
        
        # Append links to the appropriate category list
        if i == a:
            for q in links:
                ft_formal.append(q.get_attribute('href'))
        elif i == b:
            for q in links:
                ft_party.append(q.get_attribute('href'))
        elif i == d:
            for q in links:
                ft_festive.append(q.get_attribute('href'))
        else:
            for q in links:
                ft_formal.append(q.get_attribute('href'))
        
        
        time.sleep(5)  # Wait before clicking next page
        
        # Click on the next page button
        next_page_button = driver.find_element(By.XPATH, '//nav[@class="yFHi8N"]/a[11]/span |//nav[@class="yFHi8N"]/a[12]/span |//nav[@class="yFHi8N"]/a[7]/span | //nav[@class="yFHi8N"]/a[8]/span')
        next_page_button.click()
        time.sleep(5)  # Wait for the next page to load
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 22
#      20     for q in links:
#      21         ft_party.append(q.get_attribute('href'))
# ---> 22 elif i == d:
#      23     for q in links:
#      24         ft_festive.append(q.get_attribute('href'))
#
# NameError: name 'd' is not defined

# %%
ms_brand_name=[]
ms_product_name=[]
ms_price=[]
ms_product_code=[]
ms_product_type=[]
ms_category=[]

col1 = []
col2 = []
col3 = []
col4 = []
wr_type = []
m_type = []
reviews = []

size1 = []
size2 = []
size3 = []
size4 = []
r_time = []
occ = []
c_ori = []
driver = webdriver.Chrome()
for l in [ft_formal, ft_festive, ft_party]:
    for link in l:
        driver.get(link)
        time.sleep(2)

        #Finding the Product price
        try:
            price_element=driver.find_element(By.XPATH,'//div[@class="_25b18c"]/div[1]')
            if price_element:
                ms_price.append(price_element.text.replace('₹',''))
            else:
                ms_price.append('----')
        except Exception as e:
            ms_price.append('----')
        
        #Finding the Product name
        try:
            pd_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[2]')
            if pd_element:
                ms_product_name.append(pd_element.text)
            else:
                ms_product_name.append('----')
        except Exception as e:
            ms_product_name.append('----')
           
        #adding brand name 
        try:
            pdc_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[1]')
            if pdc_element:
                ms_brand_name.append(pdc_element.text.replace('SKU : ',''))
            else:
                ms_brand_name.append('----')
            
        except Exception as e:
            ms_brand_name.append('----')
        
        #adding product code
        ms_product_code.append(random.randint(10000000, 99999999))
    
        #adding category
        ms_category.append('WOMEN')
    
    # scrapping colour
        try:
            clr1 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][1]/div/div]')
            col1.append(clr1.text.strip())
        except Exception as e:
            col1.append('blue')
        try:
            clr2 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][2]/div/div]')
            col2.append(clr2.text.strip())
        except Exception as e:
            col2.append('Grey')
        try:
            clr3 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][3]/div/div]')
            col3.append(clr3.text.strip())
        except Exception as e:
            col3.append('White')
        try:
            clr4 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][4]/div/div]')
            col4.append(clr4.get_attribute('title'))
        except Exception as e:
            col4.append('white')
            
        try:
            button = driver.find_element(By.XPATH, '//div[@class="_2yIA0Y"]/div/div[2]')
            button.click()
        except Exception as e:
            pass
        
        try: #scrapping material type
        # Loop through elements from index 2 to index 7
            for i in range(1, 8):
                head = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[1]')
                if head.text == "Fabric": 
                    mate = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[2]').text
                    m_type.append(mate)
                    break  # Exit the loop once "Occasion" is found
            else:
                m_type.append('-----')  # Append '-----' if "Occasion" is not found in any iteration
        except Exception as e:
            m_type.append('-----')
    
        # adding reviews # info not available
        reviews.append(random.randint(100, 10000))

        # scrapping size 
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[1]')
            size1.append(size.text.strip())
        except Exception as e:
            size1.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[2]')
            size2.append(size.text.strip())
        except Exception as e:
            size2.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[3]')
            size3.append(size.text.strip())
        except Exception as e:
            size3.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[4]')
            size4.append(size.text.strip())
        except Exception as e:
            size4.append('-----')
    
        #adding wear type
        wr_type.append('bottom wear')
        
        # adding return time
        r_time.append('10')
        
        # product type
        try:
            last_word = pd_element.text.split()[-1]
            ms_product_type.append(last_word)
        except Exception as e:
            ms_product_type.append('-----')
        
        # occassion 
        if l == ft_festive:
            occ.append('festive')
        elif l == ft_formal:
            occ.append('formal')
        else:
            occ.append('casual')  
            
        # country of origin 
        c_ori.append('india')

# %%
data3 = pd.DataFrame({'Brand name' : ms_brand_name, 'category' : ms_category, 'product type' : ms_product_type,'product name' : ms_product_name, 'product code' : ms_product_code , 'price' :ms_price, 
                      'wear type' : wr_type, 'material type' : m_type,'colour 1' : col1, 'colour 2' :col2, 'colour 3' : col3, 'colour 4' : col4,  "reviews" : reviews,
                      "occasion" : occ, "return_ time" : r_time, "country _origin" : c_ori, 'size1' :size1, 'size2' :size2, 'size3' :size3, 'size4' :size4})
data3
data3.to_csv('fdata3', index = False)

# %% [markdown]
# # WOMENS BOTTOM WEAR

# %%
driver = webdriver.Chrome()
driver.get('https://www.flipkart.com/')

# %%
#clicking on womens top wear
s=driver.find_element(By.XPATH,'//div[@class="_3sdu8W emupdz"]/div[1]/div/div/span')
s.click()

# %%
a = 'https://www.flipkart.com/clothing-and-accessories/kurtas-ethnic-sets-and-bottoms/leggings-and-churidars/pr?sid=clo,cfv,ht7&p[]=facets.occasion%255B%255D%3DCasual&p[]=facets.ideal_for%255B%255D%3DWomen&otracker=categorytree'
b = 'https://www.flipkart.com/clothing-and-accessories/ethnic-wear/dhoti-pants/women-dhoti-pants/pr?sid=clo,cfv,emd,on4&otracker=categorytree&otracker=nmenu_sub_Women_0_Dhoti%20Pants'
c = 'https://www.flipkart.com/clothing-and-accessories/ethnic-wear/salwar-and-patiala/women-salwar-and-patiala/pr?sid=clo%2Ccfv%2C1n0%2Cops&otracker=categorytree&otracker=nmenu_sub_Women_0_Salwars+%26+Patiala&p%5B%5D=facets.occasion%255B%255D%3DFormal' 
fb = [a,b,c]

# %%
# Initialize empty lists for different shirt categories
fb_formal = []
fb_party = []
fb_festive = []
fb_casual = []

# %%
driver = webdriver.Chrome()
# Loop through each URL in the list MT
for i in fb:
    driver.get(i)
    time.sleep(10)  # Wait for the page to load
    
    # Loop through pages 1 to 6 (assuming pagination)
    for page_number in [1, 2, 3, 4, 5, 6]:
        driver.execute_script("window.scrollTo(0, 3700);")  # Scroll to the bottom of the page
        time.sleep(5)  # Wait for content to load
        
        # Find links for shirts
        links = driver.find_elements(By.XPATH, '//div[@class="_1xHGtK _373qXS"]/a')
        
        # Append links to the appropriate category list
        if i == a:
            for q in links:
                fb_casual.append(q.get_attribute('href'))
        elif i == b:
            for q in links:
                fb_festive.append(q.get_attribute('href'))
        else:
            for q in links:
                fb_formal.append(q.get_attribute('href'))
        
        
        time.sleep(5)  # Wait before clicking next page
        
        # Click on the next page button
        next_page_button = driver.find_element(By.XPATH, '//nav[@class="yFHi8N"]/a[11]/span |//nav[@class="yFHi8N"]/a[12]/span |//nav[@class="yFHi8N"]/a[7]/span | //nav[@class="yFHi8N"]/a[8]/span')
        next_page_button.click()
        time.sleep(5)  # Wait for the next page to load

# %%
ms_brand_name=[]
ms_product_name=[]
ms_price=[]
ms_product_code=[]
ms_product_type=[]
ms_category=[]

col1 = []
col2 = []
col3 = []
col4 = []
wr_type = []
m_type = []
reviews = []

size1 = []
size2 = []
size3 = []
size4 = []
r_time = []
occ = [] #ft_formal, ft_party
c_ori = []

# %%
driver = webdriver.Chrome()
for l in [fb_formal]:
    for link in l:
        driver.get(link)
        time.sleep(2)

        #Finding the Product price
        try:
            price_element=driver.find_element(By.XPATH,'//div[@class="_25b18c"]/div[1]')
            if price_element:
                ms_price.append(price_element.text.replace('₹',''))
            else:
                ms_price.append('----')
        except Exception as e:
            ms_price.append('----')
        
        #Finding the Product name
        try:
            pd_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[2]')
            if pd_element:
                ms_product_name.append(pd_element.text)
            else:
                ms_product_name.append('----')
        except Exception as e:
            ms_product_name.append('----')
           
        #adding brand name 
        try:
            pdc_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[1]')
            if pdc_element:
                ms_brand_name.append(pdc_element.text.replace('SKU : ',''))
            else:
                ms_brand_name.append('----')
            
        except Exception as e:
            ms_brand_name.append('----')
        
        #adding product code
        ms_product_code.append(random.randint(10000000, 99999999))
    
        #adding category
        ms_category.append('WOMEN')
    
    # scrapping colour
        try:
            clr1 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][1]/div/div]')
            col1.append(clr1.text.strip())
        except Exception as e:
            col1.append('blue')
        try:
            clr2 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][2]/div/div]')
            col2.append(clr2.text.strip())
        except Exception as e:
            col2.append('Grey')
        try:
            clr3 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][3]/div/div]')
            col3.append(clr3.text.strip())
        except Exception as e:
            col3.append('White')
        try:
            clr4 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][4]/div/div]')
            col4.append(clr4.get_attribute('title'))
        except Exception as e:
            col4.append('white')
            
        try:
            button = driver.find_element(By.XPATH, '//div[@class="_2yIA0Y"]/div/div[2]')
            button.click()
        except Exception as e:
            pass
        
        try: #scrapping material type
        # Loop through elements from index 2 to index 7
            for i in range(1, 8):
                head = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[1]')
                if head.text == "Fabric": 
                    mate = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[2]').text
                    m_type.append(mate)
                    break  # Exit the loop once "Occasion" is found
            else:
                m_type.append('-----')  # Append '-----' if "Occasion" is not found in any iteration
        except Exception as e:
            m_type.append('-----')
    
        # adding reviews # info not available
        reviews.append(random.randint(100, 10000))

        # scrapping size 
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[1]')
            size1.append(size.text.strip())
        except Exception as e:
            size1.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[2]')
            size2.append(size.text.strip())
        except Exception as e:
            size2.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[3]')
            size3.append(size.text.strip())
        except Exception as e:
            size3.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[4]')
            size4.append(size.text.strip())
        except Exception as e:
            size4.append('-----')
    
        #adding wear type
        wr_type.append('bottom wear')
        
        # adding return time
        r_time.append('10')
        
        # product type
        try:
            last_word = pd_element.text.split()[-1]
            ms_product_type.append(last_word)
        except Exception as e:
            ms_product_type.append('-----')
        
        # occassion 
        if l == fb_festive:
            occ.append('festive')
        elif l == fb_formal:
            occ.append('formal')
        else:
            occ.append('casual')  
            
        # country of origin 
        c_ori.append('india')

# %%
driver = webdriver.Chrome()
for l in [fb_casual]:
    for link in l:
        driver.get(link)
        time.sleep(2)

        #Finding the Product price
        try:
            price_element=driver.find_element(By.XPATH,'//div[@class="_25b18c"]/div[1]')
            if price_element:
                ms_price.append(price_element.text.replace('₹',''))
            else:
                ms_price.append('----')
        except Exception as e:
            ms_price.append('----')
        
        #Finding the Product name
        try:
            pd_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[2]')
            if pd_element:
                ms_product_name.append(pd_element.text)
            else:
                ms_product_name.append('----')
        except Exception as e:
            ms_product_name.append('----')
           
        #adding brand name 
        try:
            pdc_element=driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]/span[1]')
            if pdc_element:
                ms_brand_name.append(pdc_element.text.replace('SKU : ',''))
            else:
                ms_brand_name.append('----')
            
        except Exception as e:
            ms_brand_name.append('----')
        
        #adding product code
        ms_product_code.append(random.randint(10000000, 99999999))
    
        #adding category
        ms_category.append('WOMEN')
    
    # scrapping colour
        try:
            clr1 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][1]/div/div]')
            col1.append(clr1.text.strip())
        except Exception as e:
            col1.append('blue')
        try:
            clr2 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][2]/div/div]')
            col2.append(clr2.text.strip())
        except Exception as e:
            col2.append('Grey')
        try:
            clr3 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][3]/div/div]')
            col3.append(clr3.text.strip())
        except Exception as e:
            col3.append('White')
        try:
            clr4 = driver.find_element(By.XPATH, '//li[@class="_3V2wfe _31hAvz"][4]/div/div]')
            col4.append(clr4.get_attribute('title'))
        except Exception as e:
            col4.append('white')
            
        try:
            button = driver.find_element(By.XPATH, '//div[@class="_2yIA0Y"]/div/div[2]')
            button.click()
        except Exception as e:
            pass
        
        try: #scrapping material type
        # Loop through elements from index 2 to index 7
            for i in range(1, 8):
                head = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[1]')
                if head.text == "Fabric": 
                    mate = driver.find_element(By.XPATH, f'//div[@class="_2yIA0Y"]/div[2]/div/div/div[{i}]/div[2]').text
                    m_type.append(mate)
                    break  # Exit the loop once "Occasion" is found
            else:
                m_type.append('-----')  # Append '-----' if "Occasion" is not found in any iteration
        except Exception as e:
            m_type.append('-----')
    
        # adding reviews # info not available
        reviews.append(random.randint(100, 10000))

        # scrapping size 
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[1]')
            size1.append(size.text.strip())
        except Exception as e:
            size1.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[2]')
            size2.append(size.text.strip())
        except Exception as e:
            size2.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[3]')
            size3.append(size.text.strip())
        except Exception as e:
            size3.append('-----')
        try:
            size = driver.find_element(By.XPATH, '//div[@class="ffYZ17 _3DM78Z col col-12-12"][2]/div/div/ul/li[4]')
            size4.append(size.text.strip())
        except Exception as e:
            size4.append('-----')
    
        #adding wear type
        wr_type.append('bottom wear')
        
        # adding return time
        r_time.append('10')
        
        # product type
        try:
            last_word = pd_element.text.split()[-1]
            ms_product_type.append(last_word)
        except Exception as e:
            ms_product_type.append('-----')
        
        # occassion 
        if l == fb_festive:
            occ.append('festive')
        elif l == fb_formal:
            occ.append('formal')
        else:
            occ.append('casual')  
            
        # country of origin 
        c_ori.append('india')

# %%
data4 = pd.DataFrame({'Brand name' : ms_brand_name, 'category' : ms_category, 'product type' : ms_product_type,'product name' : ms_product_name, 'product code' : ms_product_code , 'price' :ms_price, 
                      'wear type' : wr_type, 'material type' : m_type,'colour 1' : col1, 'colour 2' :col2, 'colour 3' : col3, 'colour 4' : col4,  "reviews" : reviews,
                      "occasion" : occ, "return_ time" : r_time, "country _origin" : c_ori, 'size1' :size1, 'size2' :size2, 'size3' :size3, 'size4' :size4})
data4
data4.to_csv('fdata4', index = False)

# %%
data4
# Out:
#            Brand name category product type              product name  \
# 0                ----    WOMEN        -----                      ----
# 1                ----    WOMEN        -----                      ----
# 2        Ethniclobby     WOMEN      Patiala      Cotton Solid Patiala
# 3        Ethniclobby     WOMEN      Patiala      Cotton Solid Patiala
# 4             ONLIKE     WOMEN      Patiala      Cotton Solid Patiala
# ..                ...      ...          ...                       ...
# 475         Karigari     WOMEN     Churidar     Cotton Women Churidar
# 476         Karigari     WOMEN     Churidar     Cotton Women Churidar
# 477  Sarthak Fashion     WOMEN     Churidar     Cotton Women Churidar
# 478              ----    WOMEN        -----                      ----
# 479          ELLEVEN     WOMEN     Churidar  Polyester Women Churidar
#
#      product code price    wear type material type colour 1 colour 2 colour 3  \
# ...
